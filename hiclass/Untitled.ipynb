# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
hiclass_aless = np.loadtxt("./../hi_class/output/") 
hiclass_farb = np.loadtxt("./../EQ_hi_class//output/hi_cs2_z20_tk.dat")

# %%
plt.loglog(hiclass_aless[:,0],hiclass_aless[:,6],"b-.")
plt.loglog(hiclass_farb[:,0],hiclass_farb[:,6],"r-")

# %%
plt.loglog(hiclass_aless[:,0], np.abs(hiclass_aless[:,6] - hiclass_farb[:,6])/hiclass_farb[:,6])
